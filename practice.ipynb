# %%
import pandas as pd
bollywood = pd.read_csv('archive/bollywood.csv',encoding='latin-1')

# %%
bollywood.head()
# Out:
#    Year                                              Title  \
# 0  1920                     Balika Badhu a.k.a. Baby Bride
# 1  1920                   Daksha Yagna a.k.a. Sati Parvati
# 2  1920          Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda
# 3  1920          Kansa Vadha a.k.a. End Of The Tyrant King
# 4  1920  Katorabhar Khoon a.k.a.The Stinger Stung a.k.a...
#
#                           Director  \
# 0  P. T. Shaida (Tulsidutt Shaida)
# 1               Vishnupant Divekar
# 2                       G. V. Sane
# 3                       G. V. Sane
# 4                   S. N. Patankar
#
#                                                 Cast      Genre Release Month  \
# 0      shaida,pandit,ali,miss,tarak,bagcha,tulsidutt     social           NaN
# 1                               prabha,khalil,vaidya  mythology           NaN
# 2                                            unknown  mythology           NaN
# ...

# %%
print(bollywood.shape)
bollywood.info
# Out:
# (9682, 8)
# <bound method DataFrame.info of       Year                                              Title  \
# 0     1920                     Balika Badhu a.k.a. Baby Bride
# 1     1920                   Daksha Yagna a.k.a. Sati Parvati
# 2     1920          Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda
# 3     1920          Kansa Vadha a.k.a. End Of The Tyrant King
# 4     1920  Katorabhar Khoon a.k.a.The Stinger Stung a.k.a...
# ...    ...                                                ...
# 9677  2019                                            Panipat
# 9678  2019                                Pati, Patni Aur Woh
# 9679  2019                                         Mardaani 2
# 9680  2019                                          Dabangg 3
# 9681  2019                                          Good News
#
#                              Director  \
# 0     P. T. Shaida (Tulsidutt Shaida)
# 1                  Vishnupant Divekar
# 2                          G. V. Sane
# ...

# %%
bollywood.tail(5)
# Out:
#       Year                Title            Director  \
# 9677  2019              Panipat  Ashutosh Gowariker
# 9678  2019  Pati, Patni Aur Woh       Mudassar Aziz
# 9679  2019           Mardaani 2        Gopi Puthran
# 9680  2019            Dabangg 3         Prabhu Deva
# 9681  2019            Good News           Raj Mehta
#
#                                                    Cast           Genre  \
# 9677       Sanjay DuttArjun KapoorKriti SanonKabir Bedi   Action/battle
# 9678           Kartik AaryanBhumi PednekarAnanya Panday          Comedy
# 9679  Rani MukherjeeVikram Singh ChauhanShruti Bapna...  Crime Thriller
# 9680  Salman KhanSonakshi SinhaArbaaz KhanMahie Gill...          Action
# 9681  Akshay KumarKareena KapoorDiljit DosanjhKiara ...          Comedy
#
#      Release Month  Release Date  Highest Grosser By Year(in crores)
# 9677           DEC           6.0                                 NaN
# 9678           DEC           6.0                                 NaN
# ...

# %%
bollywood.sample(3)
# Out:
#       Year     Title              Director  \
# 5046  1975  Chaitali  Hrishikesh Mukherjee
# 4562  1969   Ittefaq           Yash Chopra
# 8535  2009       Paa              R. Balki
#
#                                                    Cast         Genre  \
# 5046                              banu,dharmendra,saira       unknown
# 4562  nanda,sujit,jagirdar,rajesh,khanna,kumar,gajan...       unknown
# 8535  balan,abhishek,bachchan,paresh,vidya,amitabh,r...  family,drama
#
#      Release Month  Release Date  Highest Grosser By Year(in crores)
# 5046           NaN           NaN                                 NaN
# 4562           NaN           NaN                                 NaN
# 8535           DEC           4.0                                 NaN

# %%
bollywood.loc[10:20,["Title","Director","Genre"]]
# Out:
#                                          Title              Director  \
# 10                               Narsinh Mehta  Suchet Singh, Shukle
# 11                                   Ram Janma            G. V. Sane
# 12                                Rama Or Maya  Suchet Singh, Shukle
# 13                                  Sairandhri       Baburao Painter
# 14                                  Shakuntala          Suchet Singh
# 15                                  Shakuntala   Shree Nath Patankar
# 16                          Shri Krishna Leela            G. V. Sane
# 17                             Shri Rama Janma            G. V. Sane
# 18       Sita Swayamwar a.k.a. Sita's Marriage   Shree Nath Patankar
# 19  The Enchanted Pills a.k.a. Vichitra Gutika        S. N. Patankar
# 20                              Vikram Urvashi      Kanjibhai Rathod
#
#               Genre
# 10       devotional
# 11        mythology
# 12        mythology
# 13        mythology
# 14        mythology
# ...

# %%
bollywood.iloc[0:5,0:3]
# Out:
#    Year                                              Title  \
# 0  1920                     Balika Badhu a.k.a. Baby Bride
# 1  1920                   Daksha Yagna a.k.a. Sati Parvati
# 2  1920          Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda
# 3  1920          Kansa Vadha a.k.a. End Of The Tyrant King
# 4  1920  Katorabhar Khoon a.k.a.The Stinger Stung a.k.a...
#
#                           Director
# 0  P. T. Shaida (Tulsidutt Shaida)
# 1               Vishnupant Divekar
# 2                       G. V. Sane
# 3                       G. V. Sane
# 4                   S. N. Patankar

# %%
bollywood.sort_values(["Year"],ascending=False)
# Out:
#       Year                           Title                         Director  \
# 9657  2019             Pal Pal Dil Ke Paas                       Sunny Deol
# 9650  2019                     Batla House                    Nikhil Advani
# 9665  2019                    Laal Kaptaan                    Navdeep Singh
# 9681  2019                       Good News                        Raj Mehta
# 9664  2019                           Ghost                     Vikram Bhatt
# ...    ...                             ...                              ...
# 11    1920                       Ram Janma                       G. V. Sane
# 10    1920                   Narsinh Mehta             Suchet Singh, Shukle
# 9     1920                 Narasinha Avtar              Shree Nath Patankar
# 15    1920                      Shakuntala              Shree Nath Patankar
# 0     1920  Balika Badhu a.k.a. Baby Bride  P. T. Shaida (Tulsidutt Shaida)
#
# ...

# %%
bollywood.sort_values(["Release Month","Year"],ascending=False)
# Out:
#       Year                                       Title             Director  \
# 9653  2019                                  Chhichhore        Nitesh Tiwari
# 9654  2019                                  Dream Girl     Raaj Shaandilyaa
# 9655  2019                                 Section 375            Ajay Bahl
# 9656  2019                             The Zoya Factor      Abhishek Sharma
# 9657  2019                         Pal Pal Dil Ke Paas           Sunny Deol
# ...    ...                                         ...                  ...
# 16    1920                          Shri Krishna Leela           G. V. Sane
# 17    1920                             Shri Rama Janma           G. V. Sane
# 18    1920       Sita Swayamwar a.k.a. Sita's Marriage  Shree Nath Patankar
# 19    1920  The Enchanted Pills a.k.a. Vichitra Gutika       S. N. Patankar
# 20    1920                              Vikram Urvashi     Kanjibhai Rathod
#
# ...

# %%
bollywood.query('Year>2000')
# Out:
#       Year                             Title            Director  \
# 7590  2001                             Abhay      Suresh Krishna
# 7591  2001  Aamdani Atthani Kharcha Rupaiyaa  K. Raghavendra Rao
# 7592  2001                            Aashiq         Indra Kumar
# 7593  2001                Afsana Dilwalon Ka       J. Om Prakash
# 7594  2001                           Ajnabee        Abbas Mustan
# ...    ...                               ...                 ...
# 9677  2019                           Panipat  Ashutosh Gowariker
# 9678  2019               Pati, Patni Aur Woh       Mudassar Aziz
# 9679  2019                        Mardaani 2        Gopi Puthran
# 9680  2019                         Dabangg 3         Prabhu Deva
# 9681  2019                         Good News           Raj Mehta
#
#                                                    Cast  \
# 7590        tandon,koirala,manisha,hassan,raveena,kamal
# 7591  tabu,juhi,lever,chawla,koppikar,isha,johnny,go...
# ...

# %%
bollywood.query('Genre=="action" and Year>2010')
# Out:
#       Year                     Title               Director  \
# 8721  2011                   Singham           Rohit Shetty
# 8735  2011                    Shabri          Lalit Marathe
# 8800  2012                      Tezz           Priyadarshan
# 8879  2013             Mumbai Mirror           Ankush Bhatt
# 8885  2013                Vishwaroop           Kamal Haasan
# 8893  2013           Zilla Ghaziabad            Anand Kumar
# 8901  2013                  Rangrezz           Priyadarshan
# 8925  2013                    Enemmy            Ashu Trikha
# 8929  2013                Policegiri        K. S. Ravikumar
# 8978  2013      Singh Saab The Great            Anil Sharma
# 8983  2013                   Dhoom 3  Vijay Krishna Acharya
# 8999  2014                    Gunday        Ali Abbas Zafar
# 9020  2014               Dishkiyaoon        Sanamjit Talwar
# 9037  2014           Angry Young Man            Ramesh Rout
# 9041  2014              Koyelaanchal            Ashu Trikha
# ...

# %%
bollywood.loc[bollywood["Director"].str.contains("chopra",case=False)]
# Out:
#       Year                                 Title  \
# 2764  1949                                Karwat
# 2917  1951                                Afsana
# 3178  1953                                 Shole
# 3207  1954                         Chandni Chowk
# 3447  1956                           Ek Hi Rasta
# ...    ...                                   ...
# 9015  2014                                     W
# 9356  2016                               Befikre
# 9458  2017                               Ittefaq
# 9607  2019       Ek Ladki Ko Dekha Toh Aisa Laga
# 9672  2019  Shikara - A Love Letter from Kashmir
#
#                                Director  \
# 2764  Prakash, B.R. Chopra (uncredited)
# 2917                       B. R. Chopra
# 3178                       B. R. Chopra
# 3207                       B. R. Chopra
# 3447                       B. R. Chopra
# ...                                 ...
# 9015                 Tarun Madan Chopra
# 9356                      Aditya Chopra
# ...

# %%
def get_era(Year):
    if Year<1980:
        return "Classic"
    elif Year<2010:
        return "Modern"
    else:
        return "Contemporary"
bollywood["Era"] = bollywood["Year"].apply(get_era)
bollywood[["Year","Title","Era"]].head()
# Out:
#    Year                                              Title      Era
# 0  1920                     Balika Badhu a.k.a. Baby Bride  Classic
# 1  1920                   Daksha Yagna a.k.a. Sati Parvati  Classic
# 2  1920          Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda  Classic
# 3  1920          Kansa Vadha a.k.a. End Of The Tyrant King  Classic
# 4  1920  Katorabhar Khoon a.k.a.The Stinger Stung a.k.a...  Classic

# %%
#bollywood.drop(columns="Cast",inplace=True)
bollywood.rename(columns={"Release Month":"month"},inplace=True)

# %%
#Find all drama movies released in December after 1990, sorted by Year newest first. 
# Show only Title, Year, Director.
bollywood[(bollywood["month"] == "DEC") & (bollywood["Year"] > 1990) & (bollywood["Genre"] == "drama")][["Title", "Year", "Director"]].sort_values("Year", ascending=False)
# Out:
#                           Title  Year              Director
# 9234                    Kajarya  2015      Madhureeta Anand
# 9115               Take It Easy  2014       Sunil Prem Vyas
# 9112  Bhopal: A Prayer for Rain  2014            Ravi Kumar
# 9113        Mumbai Delhi Mumbai  2014        Satish Rajwade
# 9118          LUV...Phir Kabhie  2014            Ajay Yadav
# 8982              What the Fish  2013         Gurmmet Singh
# 8764          The Dirty Picture  2011         Milan Luthria
# 8662              Isi Life Mein  2010        Vidhi Kasliwal
# 8660                      Mirch  2010          Vinay Shukla
# 8665       Ada... A Way of Life  2010          Tanvir Ahmad
# 8537       Raat Gayi Baat Gayi?  2009        Saurabh Shukla
# 8437           Meerabai Not Out  2008  Chandrakant Kulkarni

# %%
#Get the shape, column names, and first 3 rows of the dataframe. (3 separate lines)
bollywood.shape
# Out:
# (9682, 9)

# %%
bollywood.head(3)
# Out:
#    Year                                      Title  \
# 0  1920             Balika Badhu a.k.a. Baby Bride
# 1  1920           Daksha Yagna a.k.a. Sati Parvati
# 2  1920  Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda
#
#                           Director  \
# 0  P. T. Shaida (Tulsidutt Shaida)
# 1               Vishnupant Divekar
# 2                       G. V. Sane
#
#                                             Cast      Genre month  \
# 0  shaida,pandit,ali,miss,tarak,bagcha,tulsidutt     social   NaN
# 1                           prabha,khalil,vaidya  mythology   NaN
# 2                                        unknown  mythology   NaN
#
#    Release Date  Highest Grosser By Year(in crores)      Era
# 0           NaN                                 NaN  Classic
# 1           NaN                                 NaN  Classic
# 2           NaN                                 NaN  Classic

# %%
bollywood.columns.tolist()
# Out:
# ['Year',
#  'Title',
#  'Director',
#  'Cast',
#  'Genre',
#  'month',
#  'Release Date',
#  'Highest Grosser By Year(in crores)',
#  'Era']

# %%
#Sort the dataframe by Title alphabetically (A to Z).
bollywood.sort_values("Title").head()
# Out:
#       Year                                              Title  \
# 3266  1954  "Prisoner Of Golconda" a.k.a. "Golconda ka Qaidi"
# 471   1927  ''Sati Savitri a.k.a. Savitri Satyavan a.k.a. ...
# 6653  1991                                           100 Days
# 9518  2018                                        102 Not Out
# 6247  1987                                    108 Teerthyatra
#
#                 Director                                               Cast  \
# 3266            Premnath  shobhana,ermeline,rajendranath,premnath,rai,sa...
# 471   Pandurang Talegiri  gade,baburao,kulkarni,pandurang,varne,gangubai...
# 6653         Parto Ghosh                        madhuri,shroff,jackie,dixit
# 9518        Umesh Shukla                       Amitabh BachchanRishi Kapoor
# 6247             Rajpati                     bhatt,anand,pravin,nayan,jeetu
#
#                      Genre month  Release Date  \
# 3266               costume   NaN           NaN
# ...

# %%
#Select only the Title and Year columns and store it in a new variable called df_small.
bollywood_small = bollywood[["Title","Year"]]

# %%
bollywood_small
# Out:
#                                                   Title  Year
# 0                        Balika Badhu a.k.a. Baby Bride  1920
# 1                      Daksha Yagna a.k.a. Sati Parvati  1920
# 2             Jalandhar Vrinda a.k.a. Sati Tulsi Vrinda  1920
# 3             Kansa Vadha a.k.a. End Of The Tyrant King  1920
# 4     Katorabhar Khoon a.k.a.The Stinger Stung a.k.a...  1920
# ...                                                 ...   ...
# 9677                                            Panipat  2019
# 9678                                Pati, Patni Aur Woh  2019
# 9679                                         Mardaani 2  2019
# 9680                                          Dabangg 3  2019
# 9681                                          Good News  2019
#
# [9682 rows x 2 columns]

# %%
#Filter movies from the year 1990 exactly. How many were released that year?
bollywood.query('Year>1990').head()
# Out:
#       Year                 Title      Director  \
# 6653  1991              100 Days   Parto Ghosh
# 6654  1991  Aag Laga Do Sawan Ko    Anup Malik
# 6655  1991         Aaj Ka Samson   Kuku Kapoor
# 6656  1991         Aakhri Cheekh  Kiran Ramsay
# 6657  1991        Afsana Pyar Ka     Shahjahan
#
#                                            Cast           Genre month  \
# 6653                madhuri,shroff,jackie,dixit        thriller   NaN
# 6654                               harish,patel         unknown   NaN
# 6655    chaddha,kapoor,sahila,goga,hemant,birje  action,romance   NaN
# 6656  ghatge,dhawan,vijay,anil,arora,vijayendra          horror   NaN
# 6657                  khan,aamir,kothari,neelam         romance   NaN
#
#       Release Date  Highest Grosser By Year(in crores)     Era
# 6653           NaN                                 NaN  Modern
# 6654           NaN                                 NaN  Modern
# 6655           NaN                                 NaN  Modern
# ...

# %%
#Use .iloc to get the movie at row index 99 (the 100th row).
bollywood.iloc[100]
# Out:
# Year                                                                               1922
# Title                                 Ratnavali a.k.a. Ratnabali a.k.a. Sea Nymph Of...
# Director                                                  Jyotish Bannerjee, C. Legrand
# Cast                                  gohar,c,pandit,patience,miss,albertina,cooper,...
# Genre                                                                  mythology,legend
# month                                                                               NaN
# Release Date                                                                        NaN
# Highest Grosser By Year(in crores)                                                  NaN
# Era                                                                             Classic
# Name: 100, dtype: object

# %%
#Filter movies from EITHER "action" OR "comedy" genre.
bollywood.query('Genre=="action" or Genre=="comedy"')
# Out:
#       Year                                              Title  \
# 85    1922                                       Lady Teacher
# 101   1922                                  Sadhu Aur Shaitan
# 406   1927  At The Clang Of Fetters a.k.a. Janjir Ne Jhank...
# 412   1927               Bhedi Trishul a.k.a. Hidden Treasure
# 548   1928                                        Kelor Kirti
# ...    ...                                                ...
# 9450  2017                                               Chef
# 9452  2017                           Mein Terrorist Nahi Hoon
# 9455  2017                                      Golmaal Again
# 9473  2017                                            Firangi
# 9474  2017                                     Fukrey Returns
#
#                                   Director  \
# 85                   Dhirendranath Ganguly
# 101   Nitish Lahiri, Dhirendranath Ganguly
# 406                       Harshadrai Mehta
# ...

# %%
#Get the unique genres in the dataset. How many distinct genres are there?
bollywood["Genre"].unique()
# Out:
# <ArrowStringArray>
# [            'social',          'mythology',            'unknown',
#          'devotional',    'mythology,drama',        'documentary',
#       'social,comedy',             'legend',       'social,drama',
#          'historical',
#  ...
#        'Family Drama',   'Thriller, Comedy',       'Comedy-Drama',
#      'crime thriller',   'Action, Thriller',     'Romantic drama',
#  'Historical/Romance',       'Black Comedy',      'Action/battle',
#      'Crime Thriller']
# Length: 624, dtype: str

# %%
bollywood["Genre"].nunique()
# Out:
# 623

# %%
#Use .loc to get rows where Year is between 1970 and 1980 (inclusive). 
# Do NOT use & conditions — use .loc's between shortcut.
bollywood.loc[bollywood["Year"].between(1970,1980)]
# Out:
#       Year              Title             Director  \
# 4617  1970       Aag Aur Daag            A. Salaam
# 4618  1970     Aan Milo Sajna           Mukul Dutt
# 4619  1970  Aansoo Aur Muskan          P. Madhavan
# 4620  1970          Abhinetri     Subodh Mukherjee
# 4621  1970            Bachpan  Kotayya Pratyagatma
# ...    ...                ...                  ...
# 5534  1980         Unees-Bees        Swaroop Kumar
# 5535  1980      Yari Dushmani      Sikandar Khanna
# 5536  1980   Yeh Kaisa Insaf?  Narayana Rao Dasari
# 5537  1980  Zakhmon Ke Nishan        Diljeet Bassi
# 5538  1980              Zalim           B. Subhash
#
#                                                  Cast    Genre month  \
# 4617                         puri,joy,mukherjee,madan   action   NaN
# 4618                  vinod,asha,parekh,rajesh,khanna    drama   NaN
# 4619                                    bindu,padmini    drama   NaN
# 4620          shashi,kapoor,malini,mukherjee,deb,hema    drama   NaN
# ...

# %%
#Sort by Year descending, but if two movies share the same year, sort those by Title A→Z.
bollywood.sort_values(["Year","Title"],ascending=[False,True])
# Out:
#       Year                                       Title             Director  \
# 9601  2019             72 Hours: Martyr Who Never Died       Avinash Dhyani
# 9625  2019        Albert Pinto Ko Gussa Kyun Aata Hai?      Soumitra Ranade
# 9609  2019                                      Amavas        Bhushan Patel
# 9645  2019                               Arjun Patiala         Rohit Jugraj
# 9637  2019                                  Article 15        Anubhav Sinha
# ...    ...                                         ...                  ...
# 16    1920                          Shri Krishna Leela           G. V. Sane
# 17    1920                             Shri Rama Janma           G. V. Sane
# 18    1920       Sita Swayamwar a.k.a. Sita's Marriage  Shree Nath Patankar
# 19    1920  The Enchanted Pills a.k.a. Vichitra Gutika       S. N. Patankar
# 20    1920                              Vikram Urvashi     Kanjibhai Rathod
#
# ...

# %%
#Reset the index after filtering. Filter movies after year 2000,
#  then reset the index so it starts from 0 again.
bollywood.loc[bollywood["Year"]>2000].reset_index(drop=True)
# Out:
#       Year                             Title            Director  \
# 0     2001                             Abhay      Suresh Krishna
# 1     2001  Aamdani Atthani Kharcha Rupaiyaa  K. Raghavendra Rao
# 2     2001                            Aashiq         Indra Kumar
# 3     2001                Afsana Dilwalon Ka       J. Om Prakash
# 4     2001                           Ajnabee        Abbas Mustan
# ...    ...                               ...                 ...
# 2087  2019                           Panipat  Ashutosh Gowariker
# 2088  2019               Pati, Patni Aur Woh       Mudassar Aziz
# 2089  2019                        Mardaani 2        Gopi Puthran
# 2090  2019                         Dabangg 3         Prabhu Deva
# 2091  2019                         Good News           Raj Mehta
#
#                                                    Cast  \
# 0           tandon,koirala,manisha,hassan,raveena,kamal
# 1     tabu,juhi,lever,chawla,koppikar,isha,johnny,go...
# ...

# %%
#Add a column "decade" that shows which decade each movie is from — 
# e.g. 1950s, 1960s, 1970s…

bollywood["Decade"] = (bollywood["Year"] // 10*10).astype(str)+"s"
bollywood["Decade"].head()
# Out:
# 0    1920s
# 1    1920s
# 2    1920s
# 3    1920s
# 4    1920s
# Name: Decade, dtype: str

# %%
bollywood.loc[bollywood.Year.between(1990,2000)]
# Out:
#       Year                         Title                           Director  \
# 6553  1990  Aadhi Haqeeqat, Aadha Fasana                        Dilip Ghosh
# 6554  1990              Aadmi Aur Apsara  J. Om Prakash, K. Raghavendra Rao
# 6555  1990                  Aaj Ka Arjun                       K.C. Bokadia
# 6556  1990         Aag Ka Daag Ka Dariya                S.V. Rajendra Singh
# 6557  1990                   Aag Ka Gola                       David Dhawan
# ...    ...                           ...                                ...
# 7585  2000                       Tarkieb                    Esmayeel Shroff
# 7586  2000         Tera Jadoo Chal Gayaa                           A. Muthu
# 7587  2000                     Tere Liye                      Sanjay Gadhvi
# 7588  2000        Tune Mera Dil Le Liyaa                        B.B. Bhalla
# 7589  2000              Zindagi Zindabad   Sumitra Bhave??Sunil Sukthankar
#
# ...

# %%
bollywood.sort_values(["Year","Title"],ascending=[False,True]).head(10)
# Out:
#       Year                                 Title                    Director  \
# 9601  2019       72 Hours: Martyr Who Never Died              Avinash Dhyani
# 9625  2019  Albert Pinto Ko Gussa Kyun Aata Hai?             Soumitra Ranade
# 9609  2019                                Amavas               Bhushan Patel
# 9645  2019                         Arjun Patiala                Rohit Jugraj
# 9637  2019                            Article 15               Anubhav Sinha
# 9615  2019                                 Badla                 Sujoy Ghosh
# 9673  2019                                  Bala                Amar Kaushik
# 9650  2019                           Batla House               Nikhil Advani
# 9596  2019                         Battalion 609  Brijesh Batuknath Tripathi
# 9634  2019                                Bharat             Ali Abbas Zafar
#
#                                                    Cast               Genre  \
# ...

# %%
bollywood[bollywood["Director"].str.contains("Kumar",case=False)].count()
# Out:
# Year                                  302
# Title                                 302
# Director                              302
# Cast                                  302
# Genre                                 302
# month                                  47
# Release Date                           47
# Highest Grosser By Year(in crores)      5
# Era                                   302
# Decade                                302
# dtype: int64

# %%
import numpy as np
bollywood["old_or_new"] = np.where(bollywood["Year"]<1980,"old","new")
bollywood["old_or_new"]
# Out:
# 0       old
# 1       old
# 2       old
# 3       old
# 4       old
#        ...
# 9677    new
# 9678    new
# 9679    new
# 9680    new
# 9681    new
# Name: old_or_new, Length: 9682, dtype: str

# %%
#Get all drama OR romance movies released after 1995. 
# Reset the index. Show the first 5 rows.
bollywood.query('Genre=="Drama" or Genre=="Romance"').where(bollywood["Year"]>1995).reset_index(drop=True).head()
# Out:
#    Year                 Title                  Director  \
# 0  2018             Mukkabaaz            Anurag Kashyap
# 1  2018          Union Leader  Sanjay Patel (filmmaker)
# 2  2018               Aiyaary             Neeraj Pandey
# 3  2018   Kuchh Bheege Alfaaz                      Onir
# 4  2018  Jaane Kyun De Yaaron              Akshay Anand
#
#                                                 Cast    Genre month  \
# 0  Vineet Kumar SinghZoya HussainRavi KishanJimmy...    Drama   JAN
# 1                          Rahul BhatTillotama Shome    Drama   JAN
# 2  Sidharth MalhotraManoj BajpayeeRakul Preet Sin...    Drama   FEB
# 3                  Zain Khan DurraniGeetanjali Thapa  Romance   FEB
# 4  Raghu RajaAbhishek SharmaKabir BediChetna Pand...    Drama   FEB
#
#    Release Date  Highest Grosser By Year(in crores)           Era Decade  \
# 0          12.0                                 NaN  Contemporary  2010s
# ...

# %%
result = bollywood.loc[50:100,["Title","Genre"]]
result.query('Genre=="Action"')
# Out:
# Empty DataFrame
# Columns: [Title, Genre]
# Index: []

# %%
nocs =  pd.read_csv('./complete-pandas-tutorial/data/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios = pd.read_csv('complete-pandas-tutorial/data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios = pd.merge(bios, nocs , left_on="born_country", right_on="NOC", how="right")

# %%
bios_new = bios[bios["born_country"]=='FRA'][["name","height_cm"]]

# %%
bios_new
# Out:
#                         name  height_cm
# 33712  Jean-François Blanchy        NaN
# 33713         Arnaud Boetsch      183.0
# 33714           Jean Borotra      183.0
# 33715        Jacques Brugnon      168.0
# 33716      Nicolas Chatelain      181.0
# ...                      ...        ...
# 38850          James Clugnet        NaN
# 38851        Margaux Hackett        NaN
# 38852         Elliott Baralo        NaN
# 38853            Elisa Nakab        NaN
# 38854         André Foussard      166.0
#
# [5143 rows x 2 columns]

# %%
bios
# Out:
#         athlete_id                  name   born_date    born_city born_region  \
# 0          57056.0     Mohammad Ebrahimi  1930-04-11        Kabul       Kabul
# 1          57062.0            Kayum Ayub  1947-06-21        Kabul       Kabul
# 2          57064.0    Aka-Jahan Dastagir  1946-06-05        Kabul       Kabul
# 3          57065.0       Ghulam Dastagir  1945-07-24        Kabul       Kabul
# 4          57066.0            Ahmad Djan  1948-02-10        Kabul       Kabul
# ...            ...                   ...         ...          ...         ...
# 110661    147637.0          Donata Katai  2004-05-07       Harare      Harare
# 110662    147638.0         Ngoni Makusha  1994-06-29  Chitungwiza      Harare
# 110663    147639.0         Scott Vincent  1992-05-20       Harare      Harare
# 110664    147640.0  Peter Purcell-Gilpin  1994-07-04       Harare      Harare
# 110665    147641.0         Peter Wetzlar  1997-02-27       Harare      Harare
#
# ...

# %%
bios.query('born_country=="ZIM" & NOC=="ZIM"')
# Out:
#         athlete_id                  name   born_date    born_city born_region  \
# 110559      2049.0         Robin Sampson  1940-11-23     Bulawayo    Bulawayo
# 110560      2826.0           Byron Black  1969-10-06       Harare      Harare
# 110561      2827.0           Wayne Black  1973-11-14       Harare      Harare
# 110562      2829.0       Philip Tuckniss  1962-05-05       Harare      Harare
# 110563      7879.0         Jannie Gibson  1941-05-15     Bulawayo    Bulawayo
# ...            ...                   ...         ...          ...         ...
# 110661    147637.0          Donata Katai  2004-05-07       Harare      Harare
# 110662    147638.0         Ngoni Makusha  1994-06-29  Chitungwiza      Harare
# 110663    147639.0         Scott Vincent  1992-05-20       Harare      Harare
# 110664    147640.0  Peter Purcell-Gilpin  1994-07-04       Harare      Harare
# 110665    147641.0         Peter Wetzlar  1997-02-27       Harare      Harare
#
# ...

# %%
bios.to_csv('bios.csv',index=False)

# %%
actors= pd.read_csv('archive/bollywood-actors.csv',encoding="latin-1")
actresses= pd.read_csv('archive/bollywood-actress.csv',encoding="latin-1")

# %%
pd.concat([actors,actresses])
# Out:
#                     Name  Height(in cm)       Debut aslead role  ÿÿ
# 0    Aaditya Shrivastava            178                     NaN NaN
# 1             Aamir Khan            163                     NaN NaN
# 2             Abhay Deol            180                     NaN NaN
# 3      Abhishek Bachchan            186                     NaN NaN
# 4        Aditya Pancholi            185                     NaN NaN
# ..                   ...            ...                     ...  ..
# 129       Warina Hussain            163               Loveratri NaN
# 130          Yami Gautam            161             Vicky Donor NaN
# 131          Zaira Wasim            155                  Dangal NaN
# 132          Zarine Khan            165                    Veer NaN
# 133          Zeenat Aman            175  Hare Rama Hare Krishna NaN
#
# [273 rows x 4 columns]
